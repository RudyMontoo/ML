# %% [markdown]
# # Lecture 3

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.tensor(9)
# Out:
# tensor(9)

# %%
revenue=torch.tensor([1,2,3])
revenue[1]
# Out:
# tensor(2)

# %%
q1=torch.tensor([
    [200,220,250],
    [150,180,210],
    [300,330,360]
])

q2=torch.tensor([
    [209,231,259],
    [155,192,222],
    [375,340,375]
])

ans=q1*q2
ans
# Out:
# tensor([[ 41800,  50820,  64750],
#         [ 23250,  34560,  46620],
#         [112500, 112200, 135000]])

# %%
q1+q2
# Out:
# tensor([[409, 451, 509],
#         [305, 372, 432],
#         [675, 670, 735]])

# %%
q2-q1
# Out:
# tensor([[ 9, 11,  9],
#         [ 5, 12, 12],
#         [75, 10, 15]])

# %%
 product_prices=torch.tensor([1100, 450, 1500])

# %%
product_prices*q1
# Out:
# tensor([[220000,  99000, 375000],
#         [165000,  81000, 315000],
#         [330000, 148500, 540000]])

# %%
if torch.cuda.is_available():
    device=torch.device("cuda")
else:
    device=torch.device("cpu")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# ###simulating customer data with millons customers and 3 features(age, spending score, income)

# %%
 # col1 is income col2 is spending col3 amt
customer_data=torch.rand(1_000_000,3, device=device)
customer_data.shape
# Out:
# torch.Size([1000000, 3])

# %%
customer_data[:5]
# Out:
# tensor([[0.7523, 0.8483, 0.7534],
#         [0.3495, 0.8086, 0.1190],
#         [0.7586, 0.9803, 0.0427],
#         [0.3502, 0.0670, 0.5572],
#         [0.5602, 0.4163, 0.4189]], device='cuda:0')

# %%
high_spending=customer_data[customer_data[:,1]>0.5]
high_spending[:5]
# Out:
# tensor([[0.7523, 0.8483, 0.7534],
#         [0.3495, 0.8086, 0.1190],
#         [0.7586, 0.9803, 0.0427],
#         [0.1128, 0.8899, 0.9220],
#         [0.9666, 0.6183, 0.7715]], device='cuda:0')

# %%
high_spending.shape
# Out:
# torch.Size([499803, 3])

# %%
high_spending.to("cpu")   #use to tranfer the data from gpu to cpu
# Out:
# tensor([[0.7523, 0.8483, 0.7534],
#         [0.3495, 0.8086, 0.1190],
#         [0.7586, 0.9803, 0.0427],
#         ...,
#         [0.5443, 0.7495, 0.6483],
#         [0.0265, 0.5641, 0.9969],
#         [0.5448, 0.8908, 0.2753]])

# %% [markdown]
# # Lecture 4

# %%
units=torch.tensor([
    [220,145],
    [340,760],
    [540,231]
    ])

# %%
units.shape
# Out:
# torch.Size([3, 2])

# %%
units.dtype
# Out:
# torch.int64

# %%
units.device
# Out:
# device(type='cpu')

# %%
if torch.cuda.is_available():
    device=torch.device("cuda")
else:
    device=torch.device("cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
units.view(-1)
# convert in 1d by row wise
# Out:
# tensor([220, 145, 340, 760, 540, 231])

# %%
units.view(2,3)
# Out:
# tensor([[220, 145, 340],
#         [760, 540, 231]])

# %%
units[2][1]=34

# %%
units
# Out:
# tensor([[220, 145],
#         [340, 760],
#         [540,  34]])

# %%
# Just like numbai in terms of this similar attributes like random ones zeros and many more

# %% [markdown]
# # Lecture 7 Autograd

# %%
import torch

# %% [markdown]
# ![image.png](attachment:71e75af2-0c81-4873-8d59-570dceee9683.png)

# %%
material_cost=torch.tensor(10, requires_grad=True, dtype=torch.float16)
labor_cost=torch.tensor(5, requires_grad=True, dtype=torch.float16)

total_cost=3*material_cost**2+5*labor_cost+100
total_cost
# Out:
# tensor(425., dtype=torch.float16, grad_fn=<AddBackward0>)

# %%
# .backward() function is used for automatic differentiation
total_cost.backward()
labor_cost.grad
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[65], line 2
#       1 # .backward() function is used for automatic differentiation
# ----> 2 total_cost.backward()
#       3 labor_cost.grad
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
# ...
