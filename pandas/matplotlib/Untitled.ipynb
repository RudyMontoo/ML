# %%
import pandas as pd

# %%
df=pd.read_csv("weather_data.csv")
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df["day"],df["temperature"],color="green",label="temperature")
plt.plot(df["day"],df["windspeed"],label="windspeed")
# plt.plot(df["day"],df["event"])
plt.title("Product Sales")
plt.ylabel("yyyyy")
plt.xlabel("xxxx")
plt.legend()
plt.show()

# %%
total=df[["day","temperature","windspeed","event"]].sum()
total
# Out:
# day            1/1/20171/2/20171/3/20171/4/20171/5/20171/6/2017
# temperature                                                 182
# windspeed                                                    28
# event                                RainSunnySnowSnowRainSunny
# dtype: object

# %%
df.plot(kind="bar",x="day")
# Out:
# <Axes: xlabel='day'>
